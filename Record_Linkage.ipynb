# %% [markdown]
# # Record Linkage: Machine Learning Example

# %% [markdown]
# This example will walk you through a typical record linkage application using the recordlinkage package in Python. We will quickly address every step and end with setting up a machine learning model to classify record pairs. The steps we will be talking about are:
#
# 1. The Principles of Record Linkage
# 1. Data Pre-processing
# 2. Indexing
# 3. Record Comparison
# 4. Classification
# 5. Evaluation

# %%
# load packages 
import recordlinkage 
import pandas
import sklearn
import numpy
import scipy
import jellyfish
from recordlinkage.datasets import load_febrl4
from recordlinkage.standardise import clean
from recordlinkage.standardise import phonetic

# %% [markdown]
# ## The Principles of Record Linkage
# The goal of record linkage is to determine if pairs of records describe the same identity. For instance, this is important for removing duplicates from a data source or joining two separate data sources together. Record linkage also goes by the terms data matching, merge/purge, duplication detection, de-duping, reference matching, entity resolution, disambiguation, co-reference/anaphora in various fields.
#
# There are several approaches to record linkage that include
#     - exact matching,
#     - rule-based linking and
#     - probabilistic linking.
# - An example of **exact matching** is joining records based on social security number. This is what you already have done in SQL by joining tables by an unique identifier.
# - **Rule-based matching** involves applying a cascading set of rules that reflect the domain knowledge of the - records being linked.
# - In **probabilistic record linkages**, linkage weights are estimated to calculate the probability of a certain match.
#
# In practical applications you will need record linkage techiques to combine information addressing the same entity that is stored in different data sources. Record linkage will also help you to address the quality of different data sources. For example, if one of your databases has missing values you might be able to fill those by finding an identical pair in a different data source. Overall, the main applications of record linkage are
#     1. Merging two or more data files
#     2. Identifying the intersection of the two data sets
#     3. Updating data files (with the data row of the other data files) and imputing missing data
#     4. Entity disambiguation and de-duplication

# %%
# use expample data that come with the package
dfA, dfB = load_febrl4()

# %%
# How does the first dataset look
dfA.head()
# Out:
#              given_name   surname street_number            address_1  \
# rec_id
# rec-1070-org   michaela   neumann             8       stanley street
# rec-1016-org   courtney   painter            12    pinkerton circuit
# rec-4405-org    charles     green            38  salkauskas crescent
# rec-1288-org    vanessa      parr           905       macquoid place
# rec-3585-org    mikayla  malloney            37        randwick road
#
#                       address_2            suburb postcode state  \
# rec_id
# rec-1070-org              miami     winston hills     4223   nsw
# rec-1016-org         bega flats         richlands     4560   vic
# rec-4405-org               kela             dapto     4566   nsw
# rec-1288-org  broadbridge manor     south grafton     2135    sa
# rec-3585-org            avalind  hoppers crossing     4552   vic
#
#              date_of_birth soc_sec_id
# rec_id
# rec-1070-org      19151111    5304218
# rec-1016-org      19161214    4066625
# rec-4405-org      19480930    4365168
# rec-1288-org      19951119    9239102
# rec-3585-org      19860208    7207688

# %%
# How does the second dataset look
dfB.head()
# Out:
#                given_name    surname street_number             address_1  \
# rec_id
# rec-561-dup-0       elton        NaN             3         light setreet
# rec-2642-dup-0   mitchell      maxon            47         edkins street
# rec-608-dup-0         NaN      white            72       lambrigg street
# rec-3239-dup-0      elk i    menzies             1          lyster place
# rec-2886-dup-0        NaN  garanggar           NaN  may maxwell crescent
#
#                          address_2             suburb postcode state  \
# rec_id
# rec-561-dup-0             pinehill         windermere     3212   vic
# rec-2642-dup-0           lochaoair         north ryde     3355   nsw
# rec-608-dup-0             kelgoola  broadbeach waters     3159   vic
# rec-3239-dup-0                 NaN          northwood     2585   vic
# rec-2886-dup-0  springettst arcade        forest hill     2342   vic
#
#                date_of_birth soc_sec_id
# rec_id
# rec-561-dup-0       19651013    1551941
# rec-2642-dup-0      19390212    8859999
# rec-608-dup-0       19620216    9731855
# rec-3239-dup-0      19980624    4970481
# rec-2886-dup-0      19921016    1366884

# %% [markdown]
# ## Data Pre-processing
#
# Data pre-processing is an important step in a data anlysis project in general, in record linkage applications in particular. The goal of pre-processing is to transform messy data into a dataset that can be used in a project workflow.
#
# Linking records from different data sources comes with different challenges that need to be addressed by the analyst. The analyst must determine whether or not two entities (individuals, businesses, geographical units) on two different files are the same. This determination is not always easy. In most of the cases there is no common uniquely identifing characteristic for a entity. For example, is Bob Miller from New Yor the same person as Bob Miller from Chicago in a given dataset? This detemination has to be executed carefully because consequences of wrong linkages may be substantial (is person X the same person as the person X on the list of identified terrorists). Pre-processing can help to make better informed decisions.
#
# Pre-processing can be difficult because there are a lot of things to keep in mind. For example, data input errors, such as typos, misspellings, truncation, abbreviations, and missing values need to be corrected. Literature shows that preprocessing can improve matches. In some situations, 90% of the improvement in matching efficiency may be due to preprocessing. The most common reason why matching projects fail is lack of time and resources for data cleaning.
#
# The record linkage package comes with a "clean" add on which can help you with preprocessing. Recordlinkage’s standardise sub-module includes four built-in functions. Each of these functions tackle a different aspect of pre-processing.

# %%
## The clean() function is used to clean a single column within a data frame, where the column contains strings. 
## By default, clean() will turn all strings into lowercase and remove characters such as quotation marks & punctuation.

dfA["name_clean"] = clean(dfA["given_name"])
dfB["name_clean"] = clean(dfB["given_name"])

# %%
## The phonetic() function is used to convert strings into their corresponding phonetic codes. 
## This is particularly useful when comparing names where different possible spellings make it difficult to find 
## exact matches (Ex. Jillian and Gillian).

dfA["phonetic"] = phonetic(dfA["name_clean"], method="nysiis")
dfB["phonetic"] = phonetic(dfB["name_clean"], method="nysiis")

# %%
# How does the second dataset look
dfA.head(100)
# Out:
#               given_name        surname street_number  \
# rec_id
# rec-1070-org    michaela        neumann             8
# rec-1016-org    courtney        painter            12
# rec-4405-org     charles          green            38
# rec-1288-org     vanessa           parr           905
# rec-3585-org     mikayla       malloney            37
# rec-298-org        blake          howie             1
# rec-1985-org         NaN           lund           109
# rec-2404-org   blakeston        broadby            53
# rec-1473-org         NaN         leslie           925
# rec-453-org       edward        denholm            10
# rec-4866-org     charlie       alderson           266
# rec-4302-org       molly          roche            59
# rec-383-org        angus       mcgregor             1
# rec-420-org         kate     stephenson             8
# rec-3440-org     matthew        bissett            11
# rec-4028-org     lachlan        godfrey            45
# rec-1363-org    campbell         clarke            14
# rec-4641-org     jessica         weller           318
# rec-1300-org      joshua         corbin            83
# rec-4178-org     caitlin          basey           414
# rec-4303-org  alessandra        stanley             9
# rec-1280-org   francesco        cannell             5
# rec-4137-org        liam         schwaz          1005
# rec-1054-org    benjamin          capel           177
# rec-1826-org       kynan         dooley            92
# rec-780-org     harrison        boulter             9
# rec-85-org       joselyn          dakin            19
# rec-201-org      claudia         huxley           108
# rec-4878-org         NaN          lowry             6
# rec-4098-org        lily        warnock            68
# ...                  ...            ...           ...
# rec-3020-org     madison        herbert            14
# rec-2115-org     pearson       shepherd            13
# rec-2432-org      isaiah          warde            61
# rec-2740-org      imogen        kiosses             2
# rec-4792-org       julia        meadows            18
# rec-3756-org     lucinda        burrill            31
# rec-215-org        caleb  roberts-yates            40
# rec-391-org         noah          mason            29
# rec-3897-org        ella       estcourt            12
# rec-18-org         riley  kerr-sullivan           166
# rec-3590-org      nasyah           reid            14
# rec-3327-org        ella         browne            35
# rec-3798-org     michael       cochrane             7
# rec-2029-org    benjamin     cassimatis            23
# rec-2686-org      imogen          white            12
# rec-1807-org        maya          nevin           351
# rec-1506-org   madeleine       bradshaw            90
# rec-1614-org        jack        moscatt            15
# rec-2813-org     georgia           rees            40
# rec-1362-org         NaN      collinson             8
# rec-2011-org        ruby        grobler           128
# rec-4825-org        lara          dunis             7
# rec-1483-org   zachariah          steed            24
# rec-3075-org     william   vanderwesten            11
# rec-2010-org       layla      donaldson            71
# rec-4548-org    samantha       chandler           183
# rec-1996-org   alexander       jeffries            45
# rec-1373-org      talyah       mccarthy             8
# rec-3232-org    isabelle           hope           140
# rec-1007-org      breana         thorpe            54
#
#                              address_1                          address_2  \
# rec_id
# rec-1070-org            stanley street                              miami
# rec-1016-org         pinkerton circuit                         bega flats
# rec-4405-org       salkauskas crescent                               kela
# rec-1288-org            macquoid place                  broadbridge manor
# rec-3585-org             randwick road                            avalind
# rec-298-org             cutlack street  belmont park belted galloway stud
# rec-1985-org            caley crescent       allandale aged care facility
# rec-2404-org            traeger street                  valley of springs
# rec-1473-org           carpenter close                                NaN
# rec-453-org                corin place                          gold tyne
# rec-4866-org       hawkesbury crescent             deergarden caravn park
# rec-4302-org       willoughby crescent                       donna valley
# rec-383-org                        NaN                    rosetta village
# rec-420-org            sinclair street                     brentwood vlge
# rec-3440-org             cowcher place                       kassingbrook
# rec-4028-org            lienhop street                           sorrento
# rec-1363-org          wootton crescent                   the manor garden
# rec-4641-org        bishopbourne court                       lismore road
# rec-1300-org               tweed place                          five oaks
# rec-4178-org            pelsart street                    st francis vlge
# rec-4303-org            araluen street                          bombowlee
# rec-1280-org            ngunawal drive                   whispering pines
# rec-4137-org              elvire place                             narada
# rec-1054-org       clive steele avenue                           spq camp
# rec-1826-org           mcintyre street                             apt 27
# rec-780-org           macgregor street                         stonyridge
# rec-85-org            abernethy street                    kanangra hostel
# rec-201-org               crease place                            edellen
# rec-4878-org          hadleigh circuit                         rowethorpe
# rec-4098-org            darling street                              jeran
# ...                                ...                                ...
# rec-3020-org               cowie place                    old post office
# rec-2115-org          de graaff street                         springdale
# rec-2432-org             mcphail place                            sunbury
# rec-2740-org           quandong street                         overnewton
# rec-4792-org            araluen street            st john of god hospital
# rec-3756-org              bamir square                         corridella
# rec-215-org             millpost close                            bandera
# rec-391-org    william hudson crescent                        court units
# rec-3897-org            gellatly place                            mayfair
# rec-18-org            clem hill street                           mindaree
# rec-3590-org              groom street                      warrina lakes
# rec-3327-org               tanjil loop                          cedarview
# rec-3798-org           monaro crescent                         ballarkona
# rec-2029-org                       NaN                            yacklin
# rec-2686-org        macrossan crescent                       peridon vlge
# rec-1807-org            rapanea street                      chelsea house
# rec-1506-org            burkitt street                           mindaree
# rec-1614-org             hosking place                                NaN
# rec-2813-org        maclaurin crescent                       spring creek
# rec-1362-org            parrabel place                       fraser lodge
# rec-2011-org           lonsdale street                      tallinga park
# rec-4825-org               rodda place                           dry rush
# rec-1483-org          hamelin crescent                   surfers hawaiian
# rec-3075-org  william wilkins crescent                              wyuna
# rec-2010-org           mannheim street               sandalford homestead
# rec-4548-org           macnamara place             st johnof god hospital
# rec-1996-org          keartland street                                NaN
# rec-1373-org           carter crescent                           eldamead
# rec-3232-org       ellenborough street               grimes paddock cotge
# rec-1007-org               weipa place                          kimberley
#
#                         suburb postcode state date_of_birth soc_sec_id  \
# rec_id
# rec-1070-org     winston hills     4223   nsw      19151111    5304218
# rec-1016-org         richlands     4560   vic      19161214    4066625
# rec-4405-org             dapto     4566   nsw      19480930    4365168
# rec-1288-org     south grafton     2135    sa      19951119    9239102
# rec-3585-org  hoppers crossing     4552   vic      19860208    7207688
# rec-298-org           budgewoi     6017   vic      19250301    5180548
# rec-1985-org         mill park     4053   nsw      19180902    7074690
# rec-2404-org        north ward     3083   qld      19120907    4308555
# rec-1473-org        canterbury     2340   vic      19950608    2438058
# rec-453-org          clayfield     4221   vic      19660306    7119771
# rec-4866-org             cooma     4128   vic      19440908    1256748
# rec-4302-org           carrara     4825   nsw      19200712    1847058
# rec-383-org    chelsea heights     3020    wa      19170409    8677579
# rec-420-org               ryde     5333    sa      19051012    4182623
# rec-3440-org  surfers paradise     4037   vic      19121107    5435247
# rec-4028-org             lalor     2350    sa      19080429    9107241
# rec-1363-org         northmead     3265   vic      19220610    7658745
# rec-4641-org           padstow     2191   nsw      19600919    4837774
# rec-1300-org            keilor     4818   nsw      19721018    7955748
# rec-4178-org        daisy hill     2113   nsw      19110711    7811311
# rec-4303-org             avoca     3104   qld      19940325    8650329
# rec-1280-org          brighton     7320   nsw      19900219    2439499
# rec-4137-org            bronte     2137   tas      19470324    4505367
# rec-1054-org         woongarra     4207   qld      19090522    4415928
# rec-1826-org         woollahra     6021   qld      19310924    1493049
# rec-780-org       cecil plains     3070   nsw      19110312    5094110
# rec-85-org             manunda     3028    wa      19261205    4852063
# rec-201-org         north ryde     2464   vic      19441020    9295307
# rec-4878-org         rossmoyne     2770    sa      19350708    6616912
# rec-4098-org             exton     2154   nsw      19620520    2626334
# ...                        ...      ...   ...           ...        ...
# rec-3020-org     glenmore park     2680   nsw      19950105    9689395
# rec-2115-org     beverly hills     2650   vic      19320517    6334586
# rec-2432-org         bonnyrigg     3929   vic      19090111    8475133
# rec-2740-org           arundel     5024    sa      19751002    1581588
# rec-4792-org        crows nest     3174   nsw      19160818    7101191
# rec-3756-org         inglewood     4557   qld      19471211    4875837
# rec-215-org              cobar     3500   qld      19670914    5399458
# rec-391-org             elwood     3155    sa      19500215    8353213
# rec-3897-org           braddon     3850   nsw      19090814    2110759
# rec-18-org          oyster bay     7325   vic      19090429    7355856
# rec-3590-org       goonellabah     2775   nsw      19850813    9822354
# rec-3327-org     berkeley vale     4564   qld      19480726    6646608
# rec-3798-org            hendra     4128   qld      19361016    5263623
# rec-2029-org        thornleigh     6006   nsw           NaN    1533923
# rec-2686-org         mount isa     2088   nsw      19580528    9882514
# rec-1807-org          evanston     2033   NaN      19220204    9920408
# rec-1506-org        tuart hill     3300   nsw      19180720    9562529
# rec-1614-org     st kilda east     2600   vic      19611218    2565922
# rec-2813-org         fullarton     6233   nsw      19210305    5595588
# rec-1362-org            elwood     2420   vic      19100819    5602774
# rec-2011-org         newbridge     2105   qld      19190104    5332690
# rec-4825-org            casino     4170   nsw      19580928    2469542
# rec-1483-org     preston beach     4214   nsw      19300502    9340008
# rec-3075-org          grenfell     5290   nsw      19500801    2499394
# rec-2010-org           urangan     2713    wa      19320608    5103641
# rec-4548-org         greenwith     2047    wa      19011201    6692802
# rec-1996-org       northbridge     3043   vic      19770408    3206197
# rec-1373-org        springwood     2170   nsw      19210913    4421495
# rec-3232-org     murray bridge     6152   qld      19480522    1334359
# rec-1007-org          san remo     4660   qld      19660117    3264752
#
#               name_clean   phonetic
# rec_id
# rec-1070-org    michaela      MACAL
# rec-1016-org    courtney     CARTNY
# rec-4405-org     charles       CARL
# rec-1288-org     vanessa      VANAS
# rec-3585-org     mikayla     MACAYL
# rec-298-org        blake       BLAC
# rec-1985-org         NaN        NaN
# rec-2404-org   blakeston  BLACASTAN
# rec-1473-org         NaN        NaN
# rec-453-org       edward      EDWAD
# rec-4866-org     charlie      CARLY
# rec-4302-org       molly       MALY
# rec-383-org        angus        ANG
# rec-420-org         kate        CAT
# rec-3440-org     matthew      MATAE
# rec-4028-org     lachlan     LACLAN
# rec-1363-org    campbell    CANPBAL
# rec-4641-org     jessica      JASAC
# rec-1300-org      joshua        JAS
# rec-4178-org     caitlin     CATLAN
# rec-4303-org  alessandra   ALASANDR
# rec-1280-org   francesco   FRANCASC
# rec-4137-org        liam        LAN
# rec-1054-org    benjamin   BANJANAN
# rec-1826-org       kynan      CYNAN
# rec-780-org     harrison    HARASAN
# rec-85-org       joselyn    JASALYN
# rec-201-org      claudia       CLAD
# rec-4878-org         NaN        NaN
# rec-4098-org        lily       LALY
# ...                  ...        ...
# rec-3020-org     madison    MADASAN
# rec-2115-org     pearson     PARSAN
# rec-2432-org      isaiah         IS
# rec-2740-org      imogen     INAGAN
# rec-4792-org       julia        JAL
# rec-3756-org     lucinda     LACAND
# rec-215-org        caleb      CALAB
# rec-391-org         noah          N
# rec-3897-org        ella         EL
# rec-18-org         riley       RALY
# rec-3590-org      nasyah       NASY
# rec-3327-org        ella         EL
# rec-3798-org     michael      MACAL
# rec-2029-org    benjamin   BANJANAN
# rec-2686-org      imogen     INAGAN
# rec-1807-org        maya        MAY
# rec-1506-org   madeleine    MADALAN
# rec-1614-org        jack        JAC
# rec-2813-org     georgia       GARG
# rec-1362-org         NaN        NaN
# rec-2011-org        ruby       RABY
# rec-4825-org        lara        LAR
# rec-1483-org   zachariah      ZACAR
# rec-3075-org     william      WALAN
# rec-2010-org       layla       LAYL
# rec-4548-org    samantha     SANANT
# rec-1996-org   alexander  ALAXANDAR
# rec-1373-org      talyah       TALY
# rec-3232-org    isabelle     ISABAL
# rec-1007-org      breana       BRAN
#
# [100 rows x 12 columns]

# %% [markdown]
# ## Indexing
#
# Indexing allows you to create candidate links, which basically means identifying pairs of data rows which might refer to the same real world entity. This is also called the comparison space (matrix). There are different ways to index data. The easiest is to create a full index and consider every pair a match. This is also the least efficient method, because we will be comparing every row of one dataset with every row of the other dataset.
#
# If we had 10,000 records in data frame A and 100,000 records in data frame B, we would have 1,000,000,000 candidate links. You can see that comparing over a full index is getting inefficient when working with big data.

# %%
## Full Index
indexer = recordlinkage.FullIndex()
pairs = indexer.index(dfA, dfB)
# Out:
# WARNING:recordlinkage:The number of record pairs is large. Consider a different indexation algorithm for better performance.

# %%
## How many records do we have?
print (len(dfA), len(dfB), len(pairs))
# Out:
# (5000, 5000, 25000000)

# %% [markdown]
# We can do better if we actually include our knowledge about the data to eliminate bad link from the start. This can be done through blocking. This method includes only record pairs that are identical on one or more stored attributes of the person (or entity in general). The recordlinkage packages gives you multiple options for this. For example, you can block by using variables, which menas only links exactly equal on specified values will be kept. You can also use a neighbourhood index in which the rows in your dataframe are ranked by some value and python will only link between the rows that are closeby.

# %%
## Create Index with blocking
indexer = recordlinkage.BlockIndex(on=('given_name', 'surname'))
pairs = indexer.index(dfA, dfB)

print (len(pairs))
# Out:
# 2574

# %% [markdown]
# Here, the set of candidate links is restricted to entries with the exact same name. Think carefully about the quality of your data when using this method. If you cannot guarantee exact matches between corresponding rows, you may exclude potential matches from your set of candidate links.

# %%
## However, blocking on name might be too restrictive
indexer = recordlinkage.BlockIndex(on='postcode')
pairs = indexer.index(dfA, dfB)

print (len(pairs))
# Out:
# 28609

# %% [markdown]
# ## Record Comparison
#
# After you have created a set of candidate links, you’re ready to begin comparing the records associated with each candidate link. In recordlinkage you must initiate a Compare object prior to performing any comparison functionality between records. This object stores both dataframes, the candidate links, and a vector containing comparison results. Further, the Compare object contains the methods for performing comparisons. The code block below initializes the comparison object.

# %%
## Initializes the comparison object
compare_cl = recordlinkage.Compare()

# %% [markdown]
# Currently there are five specific comparison methods within recordlinkage: Compare.exact(), Compare.string(), Compare.numeric(), Compare.geo(), and Compare.date(). The Compare.exact() method is simple: if two values are an exact match a comparison score of 1 is returned, otherwise 0 is retured. The Compare.string() method is a bit more complicated and generates a score based on well known string-comparison algorithms (for this example Levenshtein or Jaro Winkler).

# %%
compare_cl.string('given_name', 'given_name', method='jarowinkler', threshold=0.85, label='given_name')
compare_cl.string('surname', 'surname', method='jarowinkler', threshold=0.85, label='surname')
compare_cl.exact('date_of_birth', 'date_of_birth', label='date_of_birth')
compare_cl.exact('suburb', 'suburb', label='suburb')
compare_cl.exact('state', 'state', label='state')
compare_cl.string('address_1', 'address_1', threshold=0.85, label='address_1')

# %%
## The comparing of record pairs starts when the compute method is called. 
## All attribute comparisons are stored in a DataFrame with horizontally the features and vertically the record pairs.

features = compare_cl.compute(pairs, dfA, dfB)
features.head()
# Out:
#                              given_name  surname  date_of_birth  suburb  \
# rec_id       rec_id
# rec-1070-org rec-1070-dup-0         1.0      0.0              1       0
#              rec-1124-dup-0         0.0      0.0              0       0
# rec-1124-org rec-1070-dup-0         0.0      0.0              0       0
#              rec-1124-dup-0         1.0      1.0              1       1
# rec-1016-org rec-4695-dup-0         0.0      0.0              0       0
#
#                              state  address_1
# rec_id       rec_id
# rec-1070-org rec-1070-dup-0      0        1.0
#              rec-1124-dup-0      1        0.0
# rec-1124-org rec-1070-dup-0      0        0.0
#              rec-1124-dup-0      1        1.0
# rec-1016-org rec-4695-dup-0      0        0.0

# %%
features.head()
# Out:
#                              given_name  surname  date_of_birth  suburb  \
# rec_id       rec_id
# rec-1070-org rec-1070-dup-0         1.0      0.0              1       0
#              rec-1124-dup-0         0.0      0.0              0       0
# rec-1124-org rec-1070-dup-0         0.0      0.0              0       0
#              rec-1124-dup-0         1.0      1.0              1       1
# rec-1016-org rec-4695-dup-0         0.0      0.0              0       0
#
#                              state  address_1
# rec_id       rec_id
# rec-1070-org rec-1070-dup-0      0        1.0
#              rec-1124-dup-0      1        0.0
# rec-1124-org rec-1070-dup-0      0        0.0
#              rec-1124-dup-0      1        1.0
# rec-1016-org rec-4695-dup-0      0        0.0

# %%
features.describe()
# Out:
#          given_name       surname  date_of_birth        suburb         state  \
# count  28609.000000  28609.000000   28609.000000  28609.000000  28609.000000
# mean       0.122619      0.130973       0.131322      0.109581      0.327694
# std        0.328005      0.337376       0.337758      0.312372      0.469381
# min        0.000000      0.000000       0.000000      0.000000      0.000000
# 25%        0.000000      0.000000       0.000000      0.000000      0.000000
# 50%        0.000000      0.000000       0.000000      0.000000      0.000000
# 75%        0.000000      0.000000       0.000000      0.000000      1.000000
# max        1.000000      1.000000       1.000000      1.000000      1.000000
#
#           address_1
# count  28609.000000
# mean       0.126813
# std        0.332769
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# ## Classification
#
# Now we have to decide which records belong to one person. We can do this pretty simple, but we can also use machine learning methods to classify records.

# %%
## Simple Classification: Check for how many attributes records are identical by summing the comparison results.
features.sum(axis=1).value_counts().sort_index(ascending=False)
# Out:
# 6.0     1576
# 5.0     1656
# 4.0      745
# 3.0      207
# 2.0      101
# 1.0     5611
# 0.0    18713
# dtype: int64

# %%
matches = features[features.sum(axis=1) > 3]
print(len(matches))
# Out:
# 3977

# %% [markdown]
# Now let's do this with a machine learning classifier. Keep in mind that most classifiers can not handle comparison vectors with missing values. To prevent issues with the classification algorithms. Supervised learning algorithms do need training data. Training data is data for which the true match status is known for each comparison vector. In the example in this section, we consider that the true match status of the first 5000 record pairs of our data is known.

# %%
## Generate Training Data and index
ml_pairs = matches[0:1000]
ml_matches_index = ml_pairs.index & pairs

# %% [markdown]
# The Naive Bayes classifier is a probabilistic classifier. The probabilistic record linkage framework by Fellegi and Sunter (1969) is the most well-known probabilistic classification method for record linkage. Later, it was proved that the Fellegi and Sunter method is mathematically equivalent to the Naive Bayes method in case of assuming independence between comparison variables.

# %%
## Train the classifier
nb = recordlinkage.NaiveBayesClassifier()
nb.learn(ml_pairs, ml_matches_index)

## Predict the match status for all record pairs
result_nb = nb.predict(matches)

## Predict probability for record to be a match
prob_nb = nb.prob(matches)

# %%
## Check header
prob_nb.head()
# Out:
# rec_id        rec_id
# rec-1124-org  rec-1124-dup-0    1.0
# rec-1016-org  rec-1016-dup-0    1.0
# rec-4695-org  rec-4695-dup-0    1.0
# rec-4158-org  rec-4158-dup-0    1.0
# rec-4100-org  rec-4100-dup-0    1.0
# dtype: float64

# %% [markdown]
# ## Evaluation
#
# The last step is to evaluate the results of the record linkage.

# %%
## Confusion matrix
conf_nb = recordlinkage.confusion_matrix(pairs, result_nb, len(features))
conf_nb
# Out:
# array([[ 3977, 24632],
#        [    0,     0]])

# %%
## Precision and Accuracy
precision = recordlinkage.precision(conf_nb)
accuracy = recordlinkage.accuracy(conf_nb)

# %%
print(precision)
# Out:
# 1.0

# %%
print(accuracy)
# Out:
# 0.139012198958

# %%
## The F-score for this classification is
recordlinkage.fscore(conf_nb)
# Out:
# 0.24409255508500585
